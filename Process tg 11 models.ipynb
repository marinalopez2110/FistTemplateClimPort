# %%
# %load_ext autoreload
# %autoreload 2
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
import processing_netcdf as pcdf
import geopandas as gpd
from geopandas import GeoDataFrame
import shapely.geometry 
import numpy as np
from shapely import geometry as gmty
from geofeather import to_geofeather, from_geofeather

# %%
import glob
import os

# %%
#path for 11 models
path = "/home/mlopez/EXEC/Tg_annual_11_models/"

# %%
files = list(glob.glob(os.path.join(path,'*.*')))

# %%
files
# Out:
# ['/home/mlopez/EXEC/Tg_annual_11_models/ACCESS1-3_rcp45_tg_mean_annual.nc',
#  '/home/mlopez/EXEC/Tg_annual_11_models/BNU-ESM_rcp45_tg_mean_annual.nc',
#  '/home/mlopez/EXEC/Tg_annual_11_models/CanESM2_rcp45_tg_mean_annual.nc',
#  '/home/mlopez/EXEC/Tg_annual_11_models/CMCC-CMS_rcp45_tg_mean_annual.nc',
#  '/home/mlopez/EXEC/Tg_annual_11_models/GFDL-ESM2M_rcp45_tg_mean_annual.nc',
#  '/home/mlopez/EXEC/Tg_annual_11_models/HadGEM2-CC_rcp45_tg_mean_annual.nc',
#  '/home/mlopez/EXEC/Tg_annual_11_models/INM-CM4_rcp45_tg_mean_annual.nc',
#  '/home/mlopez/EXEC/Tg_annual_11_models/IPSL-CM5A-LR_rcp45_tg_mean_annual.nc',
#  '/home/mlopez/EXEC/Tg_annual_11_models/MPI-ESM-LR_rcp45_tg_mean_annual.nc',
#  '/home/mlopez/EXEC/Tg_annual_11_models/NorESM1-M_rcp45_tg_mean_annual.nc',
#  '/home/mlopez/EXEC/Tg_annual_11_models/IPSL-CM5B-LR_rcp45_tg_mean_annual.nc']

# %% [markdown]
# # Create DF of all models

# %%
dflist = []

# %%
for file in files:
    df = pcdf.load_as_df(file)
    dflist.append(df)
# Out:
# /exec/mlopez/Code/GitHub/processing_netcdf.py:24: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'noleap', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
#   ds['time'] = index.to_datetimeindex()
# /exec/mlopez/Code/GitHub/processing_netcdf.py:24: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'noleap', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
#   ds['time'] = index.to_datetimeindex()
# /exec/mlopez/Code/GitHub/processing_netcdf.py:24: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, '360_day', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
#   ds['time'] = index.to_datetimeindex()
# /exec/mlopez/Code/GitHub/processing_netcdf.py:24: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'noleap', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
#   ds['time'] = index.to_datetimeindex()

# %%
dflist
# Out:
# [                                    tg_mean
#  lat       lon        time
#  66.623306 -89.045212 1950-01-01  258.828888
#                       1951-01-01  258.898285
#                       1952-01-01  258.709839
#                       1953-01-01  258.461304
#                       1954-01-01  259.764862
#  ...                                     ...
#  40.041039 -74.045807 2096-01-01  287.267639
#                       2097-01-01  287.343201
#                       2098-01-01  289.033142
#                       2099-01-01  287.839813
#                       2100-01-01  287.281799
#
#  [11507106 rows x 1 columns],                                     tg_mean
#  lat       lon        time
#  66.623306 -89.045212 1950-01-01  257.955170
#                       1951-01-01  256.791321
#                       1952-01-01  259.168579
#                       1953-01-01  258.776642
#                       1954-01-01  257.527466
#  ...                                     ...
#  40.041039 -74.045807 2096-01-01  287.275635
#                       2097-01-01  289.127319
#                       2098-01-01  288.509918
#                       2099-01-01  288.884155
#                       2100-01-01  288.198730
#
#  [11507106 rows x 1 columns],                                     tg_mean
#  lat       lon        time
#  66.623306 -89.045212 1950-01-01  257.085693
#                       1951-01-01  258.389740
#                       1952-01-01  258.411224
#                       1953-01-01  257.813049
#                       1954-01-01  259.148529
#  ...                                     ...
#  40.041039 -74.045807 2096-01-01  288.246490
#                       2097-01-01  288.674133
#                       2098-01-01  288.317993
#                       2099-01-01  287.446564
#                       2100-01-01  288.106812
#
#  [11507106 rows x 1 columns],                                     tg_mean
#  lat       lon        time
#  66.623306 -89.045212 1950-01-01  257.661499
#                       1951-01-01  259.650604
#                       1952-01-01  258.695526
#                       1953-01-01  258.613068
#                       1954-01-01  258.736298
#  ...                                     ...
#  40.041039 -74.045807 2096-01-01  290.193420
#                       2097-01-01  287.881073
#                       2098-01-01  287.628967
#                       2099-01-01  287.799133
#                       2100-01-01  288.197174
#
#  [11507106 rows x 1 columns],                                     tg_mean
#  lat       lon        time
#  66.623306 -89.045212 1950-01-01  259.359985
#                       1951-01-01  257.891724
#                       1952-01-01  258.406677
#                       1953-01-01  259.058777
#                       1954-01-01  259.393402
#  ...                                     ...
#  40.041039 -74.045807 2096-01-01  287.343201
#                       2097-01-01  286.741150
#                       2098-01-01  286.736542
#                       2099-01-01  286.392944
#                       2100-01-01  286.098236
#
#  [11507106 rows x 1 columns],                                     tg_mean
#  lat       lon        time
#  66.623306 -89.045212 1950-01-01  256.886414
#                       1951-01-01  257.775177
#                       1952-01-01  257.146881
#                       1953-01-01  258.244354
#                       1954-01-01  258.522583
#  ...                                     ...
#  40.041039 -74.045807 2096-01-01  289.489594
#                       2097-01-01  287.372742
#                       2098-01-01  288.842590
#                       2099-01-01  290.438416
#                       2100-01-01  289.174255
#
#  [11507106 rows x 1 columns],                                     tg_mean
#  lat       lon        time
#  66.623306 -89.045212 1950-01-01  258.635193
#                       1951-01-01  258.124695
#                       1952-01-01  259.136200
#                       1953-01-01  259.164734
#                       1954-01-01  260.328033
#  ...                                     ...
#  40.041039 -74.045807 2096-01-01  286.637360
#                       2097-01-01  286.426117
#                       2098-01-01  286.326630
#                       2099-01-01  286.937592
#                       2100-01-01  286.248108
#
#  [11507106 rows x 1 columns],                                     tg_mean
#  lat       lon        time
#  66.623306 -89.045212 1950-01-01  259.794189
#                       1951-01-01  258.864807
#                       1952-01-01  257.313568
#                       1953-01-01  259.756989
#                       1954-01-01  258.833466
#  ...                                     ...
#  40.041039 -74.045807 2096-01-01  288.255951
#                       2097-01-01  288.649231
#                       2098-01-01  287.149475
#                       2099-01-01  290.203461
#                       2100-01-01  287.348236
#
#  [11507106 rows x 1 columns],                                     tg_mean
#  lat       lon        time
#  66.623306 -89.045212 1950-01-01  258.653290
#                       1951-01-01  256.835785
#                       1952-01-01  256.559204
#                       1953-01-01  256.548126
#                       1954-01-01  259.228180
#  ...                                     ...
#  40.041039 -74.045807 2096-01-01  287.622437
#                       2097-01-01  287.997528
#                       2098-01-01  285.644012
#                       2099-01-01  287.409607
#                       2100-01-01  288.164520
#
#  [11507106 rows x 1 columns],                                     tg_mean
#  lat       lon        time
#  66.623306 -89.045212 1950-01-01  260.484924
#                       1951-01-01  259.078644
#                       1952-01-01  258.677917
#                       1953-01-01  257.989288
#                       1954-01-01  259.059174
#  ...                                     ...
#  40.041039 -74.045807 2096-01-01  287.475037
#                       2097-01-01  288.044769
#                       2098-01-01  286.913635
#                       2099-01-01  288.436249
#                       2100-01-01  287.527069
#
#  [11507106 rows x 1 columns],                                     tg_mean
#  lat       lon        time
#  66.623306 -89.045212 1950-01-01  260.071655
#                       1951-01-01  258.420990
#                       1952-01-01  259.665039
#                       1953-01-01  259.152985
#                       1954-01-01  259.997162
#  ...                                     ...
#  40.041039 -74.045807 2096-01-01  287.735748
#                       2097-01-01  288.222382
#                       2098-01-01  287.898895
#                       2099-01-01  288.221161
#                       2100-01-01  288.576843
#
#  [11507106 rows x 1 columns]]

# %%
#Takes 3 min
# %time df11 = pd.concat(dflist)
# Out:
# CPU times: user 3min 17s, sys: 3min 38s, total: 6min 56s
# Wall time: 59.9 s

# %%
df11
# Out:
#                                     tg_mean
# lat       lon        time
# 66.623306 -89.045212 1950-01-01  258.828888
#                      1951-01-01  258.898285
#                      1952-01-01  258.709839
#                      1953-01-01  258.461304
#                      1954-01-01  259.764862
# ...                                     ...
# 40.041039 -74.045807 2096-01-01  287.735748
#                      2097-01-01  288.222382
#                      2098-01-01  287.898895
#                      2099-01-01  288.221161
#                      2100-01-01  288.576843
#
# [126578166 rows x 1 columns]

# %%
dftgm = df11.reset_index()

# %%
dftgm
# Out:
#                  lat        lon       time     tg_mean
# 0          66.623306 -89.045212 1950-01-01  258.828888
# 1          66.623306 -89.045212 1951-01-01  258.898285
# 2          66.623306 -89.045212 1952-01-01  258.709839
# 3          66.623306 -89.045212 1953-01-01  258.461304
# 4          66.623306 -89.045212 1954-01-01  259.764862
# ...              ...        ...        ...         ...
# 126578161  40.041039 -74.045807 2096-01-01  287.735748
# 126578162  40.041039 -74.045807 2097-01-01  288.222382
# 126578163  40.041039 -74.045807 2098-01-01  287.898895
# 126578164  40.041039 -74.045807 2099-01-01  288.221161
# 126578165  40.041039 -74.045807 2100-01-01  288.576843
#
# [126578166 rows x 4 columns]

# %% [markdown]
# # Get the mean for 11 models

# %%
#Takes 48s
# %time dftgm2 = dftgm.groupby(["lat", "lon", "time"]).mean()
# Out:
# CPU times: user 1min 9s, sys: 3min 24s, total: 4min 33s
# Wall time: 1min 11s

# %%
dftgm2
# Out:
#                                     tg_mean
# lat       lon        time
# 40.041039 -89.045212 1950-01-01  284.512207
#                      1951-01-01  284.301483
#                      1952-01-01  284.201324
#                      1953-01-01  284.058258
#                      1954-01-01  284.223297
# ...                                     ...
# 66.623306 -61.296322 2096-01-01  266.947266
#                      2097-01-01  266.583160
#                      2098-01-01  267.383698
#                      2099-01-01  267.084015
#                      2100-01-01  266.929138
#
# [11507106 rows x 1 columns]

# %% [markdown]
# # Transform temp to Celsius

# %%
dfC = dftgm2.copy()
dfC["tg_mean"] = dfC["tg_mean"] -273.15

# %% [markdown]
# # Define 3 periods of time:

# %%
year_groups = {y:0 for y in range(1980,2011)}
year_groups.update({y:1 for y in range(2041,2071)})
year_groups.update({y:2 for y in range(2071,2101)})
#Get the mean of every period
dfC2 = dfC.reset_index()
dfp = dfC2.groupby([dfC2.time.dt.year.map(year_groups), "lat","lon"]).mean()

# %%
dfp.reset_index()
# Out:
#         time        lat        lon    tg_mean
# 0        0.0  40.041039 -89.045212  11.582137
# 1        0.0  40.041039 -88.961884  11.563147
# 2        0.0  40.041039 -88.878548  11.553229
# 3        0.0  40.041039 -88.795219  11.533276
# 4        0.0  40.041039 -88.711891  11.550668
# ...      ...        ...        ...        ...
# 228613   2.0  66.623306 -61.629639  -6.811722
# 228614   2.0  66.623306 -61.546310  -7.124964
# 228615   2.0  66.623306 -61.462978  -6.919032
# 228616   2.0  66.623306 -61.379650  -6.850576
# 228617   2.0  66.623306 -61.296322  -6.249941
#
# [228618 rows x 4 columns]

# %% [markdown]
# # Historic Period

# %% [markdown]
# 485,881/3 = 161,960. ---- instead 333,469 rows × 4 columns

# %%
df_h = dfp.query("time==0.0")
df_h.reset_index()
# Out:
#        time        lat        lon    tg_mean
# 0       0.0  40.041039 -89.045212  11.582137
# 1       0.0  40.041039 -88.961884  11.563147
# 2       0.0  40.041039 -88.878548  11.553229
# 3       0.0  40.041039 -88.795219  11.533276
# 4       0.0  40.041039 -88.711891  11.550668
# ...     ...        ...        ...        ...
# 76201   0.0  66.623306 -61.629639  -9.662173
# 76202   0.0  66.623306 -61.546310  -9.956597
# 76203   0.0  66.623306 -61.462978  -9.742899
# 76204   0.0  66.623306 -61.379650  -9.663411
# 76205   0.0  66.623306 -61.296322  -9.058446
#
# [76206 rows x 4 columns]

# %%
df2050 = dfp.query("time==1.0")
df2050.reset_index()
# Out:
#        time        lat        lon    tg_mean
# 0       1.0  40.041039 -89.045212  13.636863
# 1       1.0  40.041039 -88.961884  13.619951
# 2       1.0  40.041039 -88.878548  13.611746
# 3       1.0  40.041039 -88.795219  13.591616
# 4       1.0  40.041039 -88.711891  13.611670
# ...     ...        ...        ...        ...
# 76201   1.0  66.623306 -61.629639  -7.389808
# 76202   1.0  66.623306 -61.546310  -7.699386
# 76203   1.0  66.623306 -61.462978  -7.491785
# 76204   1.0  66.623306 -61.379650  -7.421025
# 76205   1.0  66.623306 -61.296322  -6.819813
#
# [76206 rows x 4 columns]

# %%
df2080 = dfp.query("time==2.0")
df2080.reset_index()
# Out:
#        time        lat        lon    tg_mean
# 0       2.0  40.041039 -89.045212  14.238521
# 1       2.0  40.041039 -88.961884  14.221740
# 2       2.0  40.041039 -88.878548  14.213413
# 3       2.0  40.041039 -88.795219  14.193439
# 4       2.0  40.041039 -88.711891  14.213731
# ...     ...        ...        ...        ...
# 76201   2.0  66.623306 -61.629639  -6.811722
# 76202   2.0  66.623306 -61.546310  -7.124964
# 76203   2.0  66.623306 -61.462978  -6.919032
# 76204   2.0  66.623306 -61.379650  -6.850576
# 76205   2.0  66.623306 -61.296322  -6.249941
#
# [76206 rows x 4 columns]

# %% [markdown]
# ## Import dataframe with polygons

# %%
dfpolyshape = from_geofeather('Grid-TerritoiresGuides.feather')
# Out:
# /home/mlopez/EXEC/anaconda3/envs/python37-2/lib/python3.8/site-packages/geofeather/core.py:85: UserWarning: Grid-TerritoiresGuides.feather.crs coordinate reference system file is missing. No crs will be set for this GeoDataFrame.
#   warnings.warn(

# %%
dfpolyshape
# Out:
#              lat        lon TER_GUIDE  \
# 0      52.957191 -67.712730     6opqr
# 1      52.957191 -67.629402     6opqr
# 2      52.957191 -67.546066     6opqr
# 3      52.873859 -67.796059     6opqr
# 4      52.873859 -67.712730     6opqr
# ...          ...        ...       ...
# 33193  45.041668 -72.208336        2c
# 33194  45.041668 -72.125000        2c
# 33195  45.041668 -72.041672        2c
# 33196  45.041668 -71.958336        2c
# 33197  45.041668 -71.875000        2c
#
#                                                 geometry
# 0      POLYGON ((-67.67107 52.93424, -67.67107 52.915...
# 1      POLYGON ((-67.67107 52.91553, -67.67107 52.934...
# 2      POLYGON ((-67.56730 52.91553, -67.57974 52.915...
# 3      POLYGON ((-67.75439 52.89329, -67.75439 52.832...
# 4      POLYGON ((-67.75439 52.83219, -67.75439 52.893...
# ...                                                  ...
# 33193  POLYGON ((-72.25000 45.00450, -72.25000 45.083...
# 33194  POLYGON ((-72.16666 45.00508, -72.16666 45.083...
# 33195  POLYGON ((-72.08334 45.00564, -72.08334 45.083...
# 33196  POLYGON ((-72.00000 45.00667, -72.00000 45.083...
# 33197  POLYGON ((-71.91666 45.04812, -71.91666 45.083...
#
# [33198 rows x 4 columns]

# %% [markdown]
# ## Merge data with mask

# %%
dftg11TG = pd.merge(df_h, dfpolyshape, on=["lat","lon"])

dftg11TG

dftg11TG.TER_GUIDE.value_counts()

# %% [markdown]
# # Create GeoJson for each territory

# %%
listTG = []

for tg in dftg11TG['TER_GUIDE'].unique().tolist():
    df = dftg11TG[dftg11TG.TER_GUIDE == tg]
    print (tg)
    listTG.append(df)

listTG

# %%
for tg in listTG:
    geometry = tg["geometry"]
    crs = {'init': "epsg:4326"}
    gdf = GeoDataFrame(tg, crs=crs, geometry=geometry)
    #print (gdf['TER_GUIDE'].iloc[0])
    gdf.to_file(gdf['TER_GUIDE'].iloc[0]+"_rcp45_tg_annual.json", driver="GeoJSON")
# Out:
# 1a
# 2c
# 3d
# 2b
# 2a
# 3c
# 3ab
# 4bc
# 4de
# 5ef
# 4f
# 4a
# 5jk
# 5bcd
# 5a
# 4gh
# 5hi
# 5g
# 6cdefg
# 6hi
# 6ab
# 6j
# 6mn
# 6kl
# 6opqr

# %% [markdown]
# # ---- Create GeoJson file for the complete shape----

# %%
geometry = dftg11TG["geometry"]

# %%
crs = {'init': "epsg:4326"}
gdf = GeoDataFrame(dftg11TG, crs=crs, geometry=geometry)

# %%
gdf.to_file("TG11tg.json", driver="GeoJSON")
